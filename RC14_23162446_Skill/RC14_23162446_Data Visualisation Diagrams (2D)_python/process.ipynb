# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('machine_readable.csv', index_col=0)
df.head()
# Out:
#                    AREANM                    Geography  \
# AREACD
# E06000047   County Durham  County or Unitary Authority
# E06000005      Darlington  County or Unitary Authority
# E06000001      Hartlepool  County or Unitary Authority
# E06000002   Middlesbrough  County or Unitary Authority
# E06000057  Northumberland  County or Unitary Authority
#
#                                    Indicator  \
# AREACD
# E06000047  Gross value added per hour worked
# E06000005  Gross value added per hour worked
# E06000001  Gross value added per hour worked
# E06000002  Gross value added per hour worked
# E06000057  Gross value added per hour worked
#
#                                                     Category Period Measure  \
# AREACD
# E06000047  Boosting productivity, pay, jobs and living st...   2021  Pounds
# E06000005  Boosting productivity, pay, jobs and living st...   2021  Pounds
# E06000001  Boosting productivity, pay, jobs and living st...   2021  Pounds
# ...

# %%
df.shape
# Out:
# (12404, 9)

# %%
df.describe()
# Out:
#               Value          MAD
# count  1.228500e+04  9925.000000
# mean   2.293116e+03     0.045762
# std    3.084408e+04     1.391726
# min   -3.000000e+00   -45.962723
# 25%    1.233503e+01    -0.674491
# 50%    5.700000e+01     0.000000
# 75%    8.400000e+01     0.679432
# max    2.002355e+06    34.161626

# %%
df.isnull()
# Out:
#            AREANM  Geography  Indicator  Category  Period  Measure   Unit  \
# AREACD
# E06000047   False      False      False     False   False    False  False
# E06000005   False      False      False     False   False    False  False
# E06000001   False      False      False     False   False    False  False
# E06000002   False      False      False     False   False    False  False
# E06000057   False      False      False     False   False    False  False
# ...           ...        ...        ...       ...     ...      ...    ...
# E12000005   False      False      False     False   False    False  False
# E12000006   False      False      False     False   False    False  False
# E12000007   False      False      False     False   False    False  False
# E12000008   False      False      False     False   False    False  False
# E12000009   False      False      False     False   False    False  False
#
#            Value    MAD
# AREACD
# E06000047  False  False
# ...

# %%
import matplotlib
# %matplotlib inline
from matplotlib import pyplot as plt
import seaborn as sns

# %%
sns.jointplot(x='Value',y='MAD', data=df, kind="hex")

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(7,3))
df['MAD'].hist(bins=20)
# Out:
# <Axes: >

# %%
df = pd.read_csv('datadownload.csv', index_col=0)
df.head()
# Out:
#                           Area name  Overcrowded  Occupied-to-standard  \
# Area code
# E92000001                   England         4.37                 26.79
# W92000004                     Wales         2.21                 21.45
# E12000001                North East         2.02                 22.61
# E12000002                North West         3.31                 24.65
# E12000003  Yorkshire and The Humber         2.97                 24.00
#
#            Under-occupied  Unnamed: 5  Unnamed: 6
# Area code
# E92000001           68.84         NaN         NaN
# W92000004           76.34         NaN         NaN
# E12000001           75.37         NaN         NaN
# E12000002           72.04         NaN         NaN
# E12000003           73.03         NaN         NaN

# %%
data=df[['Area name','Overcrowded','Under-occupied']]
data.head()
# Out:
#                           Area name  Overcrowded  Under-occupied
# Area code
# E92000001                   England         4.37           68.84
# W92000004                     Wales         2.21           76.34
# E12000001                North East         2.02           75.37
# E12000002                North West         3.31           72.04
# E12000003  Yorkshire and The Humber         2.97           73.03

# %%
df.drop('Unnamed: 5','Unnamed: 6',axis=1)
# Out:
#                           Area name  Overcrowded  Occupied-to-standard  \
# Area code
# E92000001                   England         4.37                 26.79
# W92000004                     Wales         2.21                 21.45
# E12000001                North East         2.02                 22.61
# E12000002                North West         3.31                 24.65
# E12000003  Yorkshire and The Humber         2.97                 24.00
# E12000004             East Midlands         3.13                 21.81
# E12000005             West Midlands         4.29                 25.38
# E12000006           East of England         3.41                 25.21
# E12000007                    London        11.09                 40.01
# E12000008                South East         3.45                 26.11
# E12000009                South West         2.39                 24.03
# NaN                             NaN          NaN                   NaN
# ...

# %%
import matplotlib
# %matplotlib inline
from matplotlib import pyplot as plt
import seaborn as sns

# %%
fig=sns.pairplot(df, 
                 plot_kws=dict(edgecolor="none", color='#dc00ff',s=6),
                 diag_kws={'color': '#dc00ff'})
# Out:
# /Users/huhuxi/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.jointplot(x='Overcrowded',y='Under-occupied', data=df, kind="hex")

# %%
df = pd.read_csv('other-species-conditions-data-oct-20-dec-20.csv', index_col=0)
df.head()
# Out:
#         InspectionType                     Condition YearMonth  Country  \
# Species
# Cattle      AnteMortem                     Diarrhoea   2020-10  England
# Cattle      AnteMortem  Emergency Slaughter on Farm    2020-10  England
# Cattle      AnteMortem  Emergency Slaughter on Farm    2020-11  England
# Cattle      AnteMortem  Emergency Slaughter on Farm    2020-12  England
# Cattle      AnteMortem     Lameness – Foot Lesion(s)   2020-10  England
#
#          NumberOfConditions  Throughput  NumberOfThroughputPlants  \
# Species
# Cattle                    2      139261                       125
# Cattle                   12      139261                       125
# Cattle                    7      140191                       125
# Cattle                    2      123531                       121
# Cattle                    1      139261                       125
#
#          PercentageOfThroughput
# Species
# Cattle                    0.001
# Cattle                    0.009
# ...

# %%
fig=sns.pairplot(df, 
                 plot_kws=dict(edgecolor="none", color='#dc00ff',s=3),
                 diag_kws={'color': '#dc00ff'})
# Out:
# /Users/huhuxi/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.jointplot(x='Throughput',y='PercentageOfThroughput', data=df, kind="hex")
